# %%
#explain the key features of Python that take it a popular choice for programming

Python's popularity as a programming language can be attributed to several key features that make it highly attractive to developers, beginners, and organizations alike. Here are some of the primary factors:

Python is popular due to its easy-to-learn syntax, versatility, and wide range of applications. Key features include:

Simple and Readable Syntax: Ideal for beginners and promotes clean, maintainable code.

Versatility: Can be used for web development, data science, automation, machine learning, and more.

Extensive Libraries: A large standard library and third-party packages speed up development.

Cross-platform: Runs on multiple operating systems with little modification.

Support for Multiple Paradigms: Works with object-oriented, functional, and procedural programming.

Active Community: A large community provides vast resources, support, and open-source contributions.

Dynamic Typing: Flexible variable handling, promoting rapid prototyping.

Great for Prototyping: Quick to write, test, and iterate code.

Integration: Easily integrates with other languages and systems.

Strong Support in Emerging Fields: Especially popular in data science, AI, and machine learning.

These features make Python a go-to language for developers across various domains.

# %%
#Describe the role of predefined keywords in Python and provide examples of how they are used in a programme

In Python, keywords are reserved words that have special meanings and functions within the Python language.
These keywords cannot be used as identifiers (such as variable names, function names, or class names)
because they are part of the Python syntax.

  Python keywords define the structure and flow of the program. They are used to control the behavior
  of the program and facilitate operations such as defining functions, classes,
  control flow (loops and conditionals), exception handling, and more.

  #1.if, elif, else: Conditional statements for decision-making


x = 10

if x > 5:
    print("x is greater than 5")
elif x == 5:
    print("x is equal to 5")
else:
    print("x is less than 5")

The if, elif, and else keywords are used to check conditions and control the flow of the program based on those conditions.

  #2.for: For loops to iterate over a sequence

    for i in range(5):
    print(i)

    The for keyword is used to create a loop that iterates over a sequence (in this case, the numbers from 0 to 4 generated by range(5)).

  #3.while: While loop to repeat a block of code as long as a condition is true

  count = 0
while count < 5:
    print(count)
    count += 1

The while keyword is used for looping until a condition evaluates to False. Here, the loop will run as long as count is less than 5.

# %%
#compare and contrast mutable and immutable objects in Python with examples

However, in Python objects are divided into two classes — mutable and immutable depending on whether an object will allow its content (state) to change after it has been created.

Mutable Objects

Mutable object — Mutable object is an object part of the data type whose contents can be changed after its creation.

Datatypes: List, Dictionary, Sets

Key Characteristics:

Mutable objects have the ability to change its content (add, remove and update elements).

This means that you change the contents of a mutable object, and anything that references that object has access to the same memory location.

Example with Lists (mutable):

Mutable object (list) my_list = [1, 2, 3] # Mutated list my_list. print(my_list)
 # Output: [99, 2, 3, 4]
 # Adding on the same line (note my_list cannot be assigned to an outer scope.) def add_on_same_line(): print('Simulate a method we add in-line.') return 7 my_list.append(add_on_same_line())
  # Using append on the classical style of function "method" call prints("my_list: {} obj_name1 append[{}]".format(my_list, add_on_same_line()))

  # Creating a mutable object (list)
my_list = [1, 2, 3]

# Modifying the list
my_list.append(4)

print(my_list)  # Output: [1, 2, 3, 4]

# Another reference to the same list
another_list = my_list
another_list[0] = 99

print(my_list)  # Output: [99, 2, 3, 4] (changes reflected in the original list)
print(another_list)  # Output: [99, 2, 3, 4]

# Creating an immutable object (tuple)
my_tuple = (1, 2, 3)

# Attempting to modify the tuple (raises an error)
try:
    my_tuple[0] = 99  # TypeError: 'tuple' object does not support item assignment
except TypeError as e:
    print(e)

# Reassigning a new tuple to the variable
my_tuple = (99, 2, 3)

print(my_tuple)  # Output: (99, 2, 3)

# %%
#Discuss the different types of operators in Python and provide examples of how they are used.

These operators are used to perform basic arithmetic operations like addition, subtraction, multiplication, etc.

1. Arithmetic Operators

+	Addition	a + b
-	Subtraction	a - b
*	Multiplication	a * b
/	Division (floating point)	a / b
//	Floor Division (integer division)	a // b
%	Modulus (remainder)	a % b
**	Exponentiation (power)	a ** b

Examples:

a = 10
b = 3

print(a + b)   # Output: 13
print(a - b)   # Output: 7
print(a * b)   # Output: 30
print(a / b)   # Output: 3.3333...
print(a // b)  # Output: 3 (floor division)
print(a % b)   # Output: 1 (remainder)
print(a ** b)  # Output: 1000 (10 raised to the power of 3)

2. Comparison (Relational) Operators
These operators compare two values and return a boolean (True or False).


==	Equal to	a == b
!=	Not equal to	a != b
>	Greater than	a > b
<	Less than	a < b
>=	Greater than or equal	a >= b
<=	Less than or equal	a <= b

Examples:

a = 10
b = 5

print(a == b)  # Output: False
print(a != b)  # Output: True
print(a > b)   # Output: True
print(a < b)   # Output: False
print(a >= b)  # Output: True
print(a <= b)  # Output: False

3. Logical Operators
These operators are used to combine conditional statements and return True or False.


and	Returns True if both conditions are true	a > 5 and b < 10
or	Returns True if either condition is true	a > 5 or b < 3
not	Reverses the result, returns True if the condition is false	not (a > 5)

Examples:

a = 10
b = 5
c = 15

print(a > 5 and b < 10)  # Output: True
print(a > 15 or b < 10)  # Output: True
print(not (a > 5))       # Output: False

4. Assignment Operators
Assignment operators are used to assign values to variables.

=	Assign value	a = 10
+=	Add and assign	a += 5
-=	Subtract and assign	a -= 3
*=	Multiply and assign	a *= 2
/=	Divide and assign	a /= 4
//=	Floor divide and assign	a //= 2
%=	Modulus and assign	a %= 3
**=	Exponentiate and assign	a **= 2

Examples:

a = 10
a += 5  # a = a + 5
print(a)  # Output: 15

a *= 2  # a = a * 2
print(a)  # Output: 30

a -= 3  # a = a - 3
print(a)  # Output: 27

5. Bitwise Operators
Bitwise operators perform operations on the binary representations of integers.

&	Bitwise AND	a & b
`	`	Bitwise OR
^	Bitwise XOR (exclusive OR)	a ^ b
~	Bitwise NOT (invert bits)	~a
<<	Left shift (shifts bits to the left)	a << b
>>	Right shift (shifts bits to the right)	a >> b

Examples:

a = 10  # binary: 1010
b = 4   # binary: 0100

print(a & b)  # Output: 0 (binary: 0000)
print(a | b)  # Output: 14 (binary: 1110)
print(a ^ b)  # Output: 14 (binary: 1110)
print(~a)     # Output: -11 (binary: 11110101)
print(a << 2) # Output: 40 (binary: 101000)
print(a >> 2) # Output: 2  (binary: 0010)

# %%
#explain the concept of type casting in Python with examples

Type casting is the process of converting one data type to another in Python.
 This can be useful when you need to perform operations that require a specific data type. Python supports both implicit and explicit type casting.

1. Implicit Type Casting
In implicit type casting, Python automatically converts one data type to another without any explicit instruction from the programmer.
This usually happens when performing operations between different types, where Python safely converts one type to another to avoid data loss.

Example:

# Implicitly converting integer to float
num_int = 10
num_float = 3.5

# Adding int and float
result = num_int + num_float

print("Result:", result)        # Output: 13.5
print("Type of result:", type(result))  # Output: <class 'float'>

2. Explicit Type Casting
In explicit type casting, also known as type conversion, the programmer explicitly converts one data type to another using built-in Python functions such as:

int(): Converts to an integer
float(): Converts to a float
str(): Converts to a string
list(): Converts to a list
tuple(): Converts to a tuple
set(): Converts to a set

Example:

# Converting float to int
num_float = 7.8
num_int = int(num_float)
print("Integer:", num_int)  # Output: 7

# Converting string to integer
str_number = "100"
num = int(str_number)
print("Converted number:", num)  # Output: 100

# Converting integer to string
num = 25
str_num = str(num)
print("String:", str_num)        # Output: '25'
print("Type of str_num:", type(str_num))  # Output: <class 'str'>

Type Casting with Containers
You can also convert between different types of containers (like lists, tuples, sets, etc.).

Example:

# Converting list to tuple and set
my_list = [1, 2, 3, 4]
my_tuple = tuple(my_list)
my_set = set(my_list)

print("Tuple:", my_tuple)  # Output: (1, 2, 3, 4)
print("Set:", my_set)      # Output: {1, 2, 3, 4}

# Converting set to list
my_set = {10, 20, 30}
my_list = list(my_set)
print("List:", my_list)    # Output: [10, 20, 30]

# %%
#How do conditional statements work in Python? Illustrate with examples.

Conditional statements in Python allow you to control the flow of your program based on certain conditions.
These statements help your program make decisions by executing different blocks of code depending on whether a condition is True or False.

The most common conditional statements in Python are:

if
elif (short for "else if")
else

Syntax:

if condition:
    # Code block executed if condition is True
elif another_condition:
    # Code block executed if the previous condition was False, but this one is True
else:
    # Code block executed if all previous conditions are False

Example 1 : if statement

num = 10

if num > 5:
    print("The number is greater than 5")  # Output: The number is greater than 5

The condition num > 5 evaluates to True, so the code block inside the if statement is executed.

Example 2: if, elif, and else statements

age = 18

if age < 18:
    print("You are a minor.")
elif age == 18:
    print("You are exactly 18 years old.")
else:
    print("You are an adult.")
output:
You are exactly 18 years old.

Example 3: Nested if statements

number = 15

if number > 10:
    print("The number is greater than 10.")
    if number % 2 == 0:
        print("It is also an even number.")
    else:
        print("It is an odd number.")
output:
The number is greater than 10.
It is an odd number.

Example 4: Using if with Multiple Conditions
You can combine conditions using logical operators like and, or, and not.

x = 5
y = 10

if x > 0 and y > 0:
    print("Both numbers are positive")  # Output: Both numbers are positive

if x > 0 or y < 0:
    print("At least one of the numbers is positive")  # Output: At least one of the numbers is positive

if not (x > 10):
    print("x is not greater than 10")  # Output: x is not greater than 10

# %%
#Describe the different types of loops in Python and their use cases with examples.

Loops in Python are used to repeat a block of code multiple times,
which is particularly useful when you want to execute a piece of code repeatedly based on a condition or over a collection of items.

Python has two main types of loops:

for loop: Used for iterating over a sequence (like a list, tuple, dictionary, set, or string).
while loop: Used for repeating a block of code as long as a certain condition is True.
Additionally, there are loop control statements such as:

break: Terminates the loop completely.
continue: Skips the current iteration and moves to the next.
pass: Does nothing; acts as a placeholder.

1. for Loop
The for loop is used to iterate over a sequence (like lists, tuples, strings, or ranges). It executes the code block for each item in the sequence.

Syntax:
for item in sequence:
    # Code block

Example 1: Iterating Over a List:

fruits = ["apple", "banana", "cherry"]
for fruit in fruits:
    print(fruit)
output:
apple
banana
cherry

Example 2: Using range() with a for Loop
The range() function generates a sequence of numbers.

# Print numbers from 0 to 4
for num in range(5):
    print(num)
output:
0
1
2
3
4

Example 3: Iterating Over a String

text = "Python"
for char in text:
    print(char)
output:
P
y
t
h
o
n

2. while Loop
The while loop repeats a block of code as long as a specified condition is True.

Syntax:
while condition:
    # Code block

Example 1: Basic while Loop

count = 0
while count < 5:
    print(count)
    count += 1
output:
0
1
2
3
4

Example 2: Using while with User Input

password = ""
while password != "secret":
    password = input("Enter the password: ")
print("Access granted!")

The loop continues until the user enters the correct password.

Loop Control Statements
1. break Statement
The break statement terminates the loop prematurely.

Example:

for num in range(10):
    if num == 5:
        break
    print(num)
output:
0
1
2
3
4

Explanation: The loop stops when num is 5.

2. continue Statement
The continue statement skips the current iteration and moves to the next one.

Examples:

for num in range(5):
    if num == 3:
        continue
    print(num)
output:
0
1
2
4

Explanation: The number 3 is skipped.

3. pass Statement
The pass statement does nothing and is used as a placeholder.

Examples:

for i in range(3):
    pass  # Placeholder for future code
print("Loop completed.")
output:
Loop completed.
